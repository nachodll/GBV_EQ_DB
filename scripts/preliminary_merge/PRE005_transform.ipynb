# %%
import os

import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
root_path = os.getenv("ROOT_PATH")
datasets_dir = os.path.join(root_path, "datasets", "raw", "INE", "INE011-DenunciasIncoadasTipoInfracción.csv")
df = pd.read_csv(datasets_dir, sep=";")
df
# Out:
#                 Tipo de infracción Comunidades y ciudades autónomas  Periodo  \
# 0               Total Infracciones                   Total Nacional     2024
# 1               Total Infracciones                   Total Nacional     2023
# 2               Total Infracciones                   Total Nacional     2022
# 3               Total Infracciones                   Total Nacional     2021
# 4               Total Infracciones                   Total Nacional     2020
# ...                            ...                              ...      ...
# 5315  Otras faltas sin especificar                          Melilla     2015
# 5316  Otras faltas sin especificar                          Melilla     2014
# 5317  Otras faltas sin especificar                          Melilla     2013
# 5318  Otras faltas sin especificar                          Melilla     2012
# 5319  Otras faltas sin especificar                          Melilla     2011
#
#        Total
# 0     44.718
# 1     47.086
# ...

# %%
df.to_csv(datasets_dir, index=False)
